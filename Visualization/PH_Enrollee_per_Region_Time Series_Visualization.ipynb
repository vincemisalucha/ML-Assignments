# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('C:/Users/Admin/Desktop/total_enroll.csv')

# %%
df.head()
# Out:
#      Region      Division Unnamed: 2  Enrollment_2012  Enrollment_2011  \
# 0  Region I  Ilocos Norte      Total          56473.0          55885.0
# 1  Region I  Ilocos Norte       Male          29591.0          29225.0
# 2  Region I  Ilocos Norte     Female          26882.0          26660.0
# 3  Region I    Ilocos Sur      Total          69652.0          69871.0
# 4  Region I    Ilocos Sur       Male          36657.0          36659.0
#
#    Enrollment_2010  Enrollment_2009  Enrollment_2008  Enrollment_2007  \
# 0          54573.0          54185.0          54134.0          53879.0
# 1          28627.0          28381.0          28315.0          28132.0
# 2          25946.0          25804.0          25819.0          25747.0
# 3          68563.0          67522.0          66430.0          66210.0
# 4          35902.0          35345.0          34709.0          34649.0
#
#    Enrollment_2006  Enrollment_2005
# 0          53595.0          53546.0
# 1          27940.0          27801.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Region           687 non-null    object
#  1   Division         678 non-null    object
#  2   Unnamed: 2       681 non-null    object
#  3   Enrollment_2012  681 non-null    float64
#  4   Enrollment_2011  681 non-null    float64
#  5   Enrollment_2010  681 non-null    float64
#  6   Enrollment_2009  681 non-null    float64
#  7   Enrollment_2008  681 non-null    float64
#  8   Enrollment_2007  681 non-null    float64
#  9   Enrollment_2006  681 non-null    float64
#  10  Enrollment_2005  681 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 59.2+ KB

# %%
df.describe()
# Out:
#        Enrollment_2012  Enrollment_2011  Enrollment_2010  Enrollment_2009  \
# count     6.810000e+02     6.810000e+02     6.810000e+02     6.810000e+02
# mean      1.168237e+05     1.165365e+05     1.145638e+05     1.126091e+05
# std       6.370053e+05     6.352683e+05     6.244147e+05     6.138868e+05
# min       0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%       1.259500e+04     1.221300e+04     1.200900e+04     1.150700e+04
# 50%       2.653200e+04     2.693800e+04     2.658000e+04     2.552900e+04
# 75%       6.902300e+04     6.986400e+04     6.976500e+04     7.044800e+04
# max       1.325949e+07     1.322689e+07     1.300299e+07     1.278113e+07
#
#        Enrollment_2008  Enrollment_2007  Enrollment_2006  Enrollment_2005
# count     6.810000e+02     6.810000e+02     6.810000e+02     6.810000e+02
# mean      1.106676e+05     1.084071e+05     1.064640e+05     1.055733e+05
# std       6.033077e+05     5.910675e+05     5.805342e+05     5.755914e+05
# ...

# %%
reg_combine = df[['Region', 
                  'Enrollment_2005', 
                  'Enrollment_2006',
                  'Enrollment_2007', 
                 'Enrollment_2008', 
                 'Enrollment_2009',
                 'Enrollment_2010',
                 'Enrollment_2011',
                 'Enrollment_2012']].groupby('Region').sum()
reg_combine
# Out:
#                                              Enrollment_2005  Enrollment_2006  \
# Region
# ARMM                                               2220160.0        2257508.0
# Aggregated by: Division                                  0.0              0.0
# CAR                                                 838080.0         842080.0
# CARAGA                                              713216.0         710312.0
# CARAGA Subtotal                                     713216.0         710312.0
# Department of Education                                  0.0              0.0
# Enhanced Basic Education Information System              0.0              0.0
# Multi-Year Performance Indicators                        0.0              0.0
# NCR                                                4593292.0        4710660.0
# National Grand total                              23965132.0       24167322.0
# Public Elementary Schools                                0.0              0.0
# ...

# %%
df['Region'].unique()
# Out:
# array(['Region I', 'Region II', 'Region III', 'Region IV-A',
#        'Region IV-A Subtotal', 'Region IV-B', 'Region V', 'Region VI',
#        'Region VII', 'Region VIII', 'Region VIII Subtotal', 'Region IX',
#        'Region IX Subtotal', 'Region X', 'Region X Subtotal', 'Region XI',
#        'Region XI Subtotal', 'Region XII', 'Region XII Subtotal',
#        'CARAGA', 'CARAGA Subtotal', 'ARMM', 'CAR', 'NCR',
#        'National Grand total', nan, 'Department of Education',
#        'Enhanced Basic Education Information System',
#        'Multi-Year Performance Indicators', 'Total School Enrollment',
#        'Public Elementary Schools', 'Aggregated by: Division'],
#       dtype=object)

# %%
reg_combine = reg_combine.loc[reg_combine["Enrollment_2005"] != 0]

# %%
reg_combine
# Out:
#                       Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Region
# ARMM                        2220160.0        2257508.0        2477884.0
# CAR                          838080.0         842080.0         841928.0
# CARAGA                       713216.0         710312.0         730842.0
# CARAGA Subtotal              713216.0         710312.0         730842.0
# NCR                         4593292.0        4710660.0        4798240.0
# National Grand total       23965132.0       24167322.0       24608414.0
# Region I                    2443044.0        2430680.0        2433456.0
# Region II                   1725892.0        1709476.0        1697608.0
# Region III                  4791612.0        4850668.0        4922264.0
# Region IV-A                 2761352.0        2814024.0        2864832.0
# Region IV-A Subtotal        2761352.0        2814024.0        2864832.0
# Region IV-B                 1713816.0        1736184.0        1745724.0
# ...

# %%
reg_combine = reg_combine.drop(labels=['National Grand total', 
                         'CARAGA Subtotal', 
                         'Region IV-A Subtotal', 
                         'Region IX Subtotal', 
                         'Region VIII Subtotal',
                        'Region X Subtotal',
                        'Region XI Subtotal',
                        'Region XII Subtotal'], axis=0)

# %%
reg_combine
# Out:
#              Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Region
# ARMM               2220160.0        2257508.0        2477884.0
# CAR                 838080.0         842080.0         841928.0
# CARAGA              713216.0         710312.0         730842.0
# NCR                4593292.0        4710660.0        4798240.0
# Region I           2443044.0        2430680.0        2433456.0
# Region II          1725892.0        1709476.0        1697608.0
# Region III         4791612.0        4850668.0        4922264.0
# Region IV-A        2761352.0        2814024.0        2864832.0
# Region IV-B        1713816.0        1736184.0        1745724.0
# Region IX          1047464.0        1050558.0        1064996.0
# Region V           3559360.0        3594436.0        3655104.0
# Region VI          3928652.0        3920304.0        3922412.0
# Region VII         3569984.0        3607660.0        3667988.0
# Region VIII        1309284.0        1312072.0        1337606.0
# ...

# %%
reg_combine.sort_values('Enrollment_2012', ascending=False)
# Out:
#              Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Region
# Region III         4791612.0        4850668.0        4922264.0
# NCR                4593292.0        4710660.0        4798240.0
# Region VI          3928652.0        3920304.0        3922412.0
# Region VII         3569984.0        3607660.0        3667988.0
# Region V           3559360.0        3594436.0        3655104.0
# Region IV-A        2761352.0        2814024.0        2864832.0
# Region I           2443044.0        2430680.0        2433456.0
# ARMM               2220160.0        2257508.0        2477884.0
# Region IV-B        1713816.0        1736184.0        1745724.0
# Region II          1725892.0        1709476.0        1697608.0
# Region VIII        1309284.0        1312072.0        1337606.0
# Region XI          1175122.0        1161618.0        1180764.0
# Region X           1184942.0        1191424.0        1214028.0
# Region XII         1081806.0        1097486.0        1134042.0
# ...

# %%
reg_combine.sort_values('Enrollment_2012', ascending=False).iloc[0:6]
# Out:
#              Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Region
# Region III         4791612.0        4850668.0        4922264.0
# NCR                4593292.0        4710660.0        4798240.0
# Region VI          3928652.0        3920304.0        3922412.0
# Region VII         3569984.0        3607660.0        3667988.0
# Region V           3559360.0        3594436.0        3655104.0
# Region IV-A        2761352.0        2814024.0        2864832.0
#
#              Enrollment_2008  Enrollment_2009  Enrollment_2010  \
# Region
# Region III         4999848.0        5088004.0        5148768.0
# NCR                4877332.0        4913580.0        4927560.0
# Region VI          3931256.0        3981236.0        4007828.0
# Region VII         3743956.0        3828924.0        3905232.0
# Region V           3718724.0        3798812.0        3870988.0
# Region IV-A        2924880.0        2985364.0        3049832.0
#
#              Enrollment_2011  Enrollment_2012
# Region
# ...

# %%
df6 = reg_combine.sort_values('Enrollment_2012', ascending=False).iloc[0:6]
plt.figure(figsize=(20, 9))
for x in df6.index:
    plt.plot(df6.loc[x], label=x)
plt.legend(loc=2)
plt.title('2012 Top 6')
# Out:
# Text(0.5, 1.0, '2012 Top 6')

# %%
reg_combine.sort_values('Enrollment_2012', ascending=False).iloc[6:12]
# Out:
#              Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Region
# Region I           2443044.0        2430680.0        2433456.0
# ARMM               2220160.0        2257508.0        2477884.0
# Region IV-B        1713816.0        1736184.0        1745724.0
# Region II          1725892.0        1709476.0        1697608.0
# Region VIII        1309284.0        1312072.0        1337606.0
# Region XI          1175122.0        1161618.0        1180764.0
#
#              Enrollment_2008  Enrollment_2009  Enrollment_2010  \
# Region
# Region I           2452736.0        2465800.0        2474664.0
# ARMM               2653648.0        2757620.0        2844988.0
# Region IV-B        1783636.0        1814520.0        1843464.0
# Region II          1704328.0        1693484.0        1695104.0
# Region VIII        1366804.0        1386942.0        1421418.0
# Region XI          1212940.0        1258568.0        1312142.0
#
#              Enrollment_2011  Enrollment_2012
# Region
# ...

# %%
df12 = reg_combine.sort_values('Enrollment_2012', ascending=False).iloc[6:12]
plt.figure(figsize=(20, 9))
for x in df12.index:
    plt.plot(df12.loc[x], label=x)
plt.legend(loc=2)
plt.title('2012 Top 7 to 12')
# Out:
# Text(0.5, 1.0, '2012 Top 7 to 12')

# %%
reg_combine.sort_values('Enrollment_2012', ascending=False).iloc[12:]
# Out:
#             Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Region
# Region X          1184942.0        1191424.0        1214028.0
# Region XII        1081806.0        1097486.0        1134042.0
# Region IX         1047464.0        1050558.0        1064996.0
# CAR                838080.0         842080.0         841928.0
# CARAGA             713216.0         710312.0         730842.0
#
#             Enrollment_2008  Enrollment_2009  Enrollment_2010  \
# Region
# Region X          1248162.0        1258098.0        1285128.0
# Region XII        1174078.0        1199024.0        1220856.0
# Region IX         1085054.0        1107756.0        1132890.0
# CAR                849456.0         862588.0         869768.0
# CARAGA             752174.0         764226.0         789540.0
#
#             Enrollment_2011  Enrollment_2012
# Region
# Region X          1314870.0        1315344.0
# Region XII        1248766.0        1255434.0
# Region IX         1168166.0        1160826.0
# ...

# %%
df17 = reg_combine.sort_values('Enrollment_2012', ascending=False).iloc[12:]
plt.figure(figsize=(20, 9))
for x in df17.index:
    plt.plot(df17.loc[x], label=x)
plt.legend(loc=2)
plt.title('2012 Top 13 to 17')
# Out:
# Text(0.5, 1.0, '2012 Top 13 to 17')

# %%
plt.figure(figsize=(20, 9))
for x in reg_combine.index:
    plt.plot(reg_combine.loc[x], label=x)
plt.legend(loc=2)

# %%
reg_combine2 = pd.DataFrame(reg_combine.sort_values(by='Enrollment'))
reg_combine2['Region'] = reg_combine.index

# %%
reg_combine.columns
# Out:
# Index(['Enrollment_2005', 'Enrollment_2006', 'Enrollment_2007',
#        'Enrollment_2008', 'Enrollment_2009', 'Enrollment_2010',
#        'Enrollment_2011', 'Enrollment_2012', 'Region'],
#       dtype='object')

# %%
reg_combine2
# Out:
#              Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Region
# ARMM               2220160.0        2257508.0        2477884.0
# CAR                 838080.0         842080.0         841928.0
# CARAGA              713216.0         710312.0         730842.0
# NCR                4593292.0        4710660.0        4798240.0
# Region I           2443044.0        2430680.0        2433456.0
# Region II          1725892.0        1709476.0        1697608.0
# Region III         4791612.0        4850668.0        4922264.0
# Region IV-A        2761352.0        2814024.0        2864832.0
# Region IV-B        1713816.0        1736184.0        1745724.0
# Region IX          1047464.0        1050558.0        1064996.0
# Region V           3559360.0        3594436.0        3655104.0
# Region VI          3928652.0        3920304.0        3922412.0
# Region VII         3569984.0        3607660.0        3667988.0
# Region VIII        1309284.0        1312072.0        1337606.0
# ...

# %%
reg_combine2[['Region', 'Enrollment_2012']].sort_values(by='Enrollment_2012', ascending=False).head(8)
# Out:
#                   Region  Enrollment_2012
# Region
# Region III    Region III        5260428.0
# NCR                  NCR        4984476.0
# Region VI      Region VI        4151544.0
# Region VII    Region VII        4121428.0
# Region V        Region V        3955148.0
# Region IV-A  Region IV-A        3210082.0
# Region I        Region I        2516920.0
# ARMM                ARMM        2500664.0

# %%
import seaborn as sns

# %%
reg_combine.columns
# Out:
# Index(['Enrollment_2005', 'Enrollment_2006', 'Enrollment_2007',
#        'Enrollment_2008', 'Enrollment_2009', 'Enrollment_2010',
#        'Enrollment_2011', 'Enrollment_2012', 'Region'],
#       dtype='object')

# %%
df.head()
# Out:
#      Region      Division Unnamed: 2  Enrollment_2012  Enrollment_2011  \
# 0  Region I  Ilocos Norte      Total          56473.0          55885.0
# 1  Region I  Ilocos Norte       Male          29591.0          29225.0
# 2  Region I  Ilocos Norte     Female          26882.0          26660.0
# 3  Region I    Ilocos Sur      Total          69652.0          69871.0
# 4  Region I    Ilocos Sur       Male          36657.0          36659.0
#
#    Enrollment_2010  Enrollment_2009  Enrollment_2008  Enrollment_2007  \
# 0          54573.0          54185.0          54134.0          53879.0
# 1          28627.0          28381.0          28315.0          28132.0
# 2          25946.0          25804.0          25819.0          25747.0
# 3          68563.0          67522.0          66430.0          66210.0
# 4          35902.0          35345.0          34709.0          34649.0
#
#    Enrollment_2006  Enrollment_2005
# 0          53595.0          53546.0
# 1          27940.0          27801.0
# ...

# %%
div_combine = df[['Region',
                  'Division', 
                  'Enrollment_2005', 
                  'Enrollment_2006',
                  'Enrollment_2007', 
                 'Enrollment_2008', 
                 'Enrollment_2009',
                 'Enrollment_2010',
                 'Enrollment_2011',
                 'Enrollment_2012']].groupby('Division').sum()
div_combine
# Out:
#                      Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Division
# ARMM                       1110080.0        1128754.0        1238942.0
# Abra                         60146.0          60016.0          60436.0
# Agusan del Norte             95832.0          97324.0          99570.0
# Agusan del Sur              194692.0         190936.0         194624.0
# Aklan                       152972.0         152644.0         152834.0
# ...                              ...              ...              ...
# Zambales                    135872.0         136578.0         140224.0
# Zamboanga City              218408.0         221990.0         229780.0
# Zamboanga Sibugay           181374.0         179314.0         179140.0
# Zamboanga del Norte         263768.0         267626.0         273756.0
# Zamboanga del Sur           251746.0         248304.0         246466.0
#
#                      Enrollment_2008  Enrollment_2009  Enrollment_2010  \
# Division
# ...

# %%
ncr_combine = df[['Region',
                  'Division', 
                  'Enrollment_2005', 
                  'Enrollment_2006',
                  'Enrollment_2007', 
                 'Enrollment_2008', 
                 'Enrollment_2009',
                 'Enrollment_2010',
                 'Enrollment_2011',
                 'Enrollment_2012']].groupby('Division').sum()

# %%
ncr_combine = df[df['Region'] == 'NCR']

# %%
ncr_combine = ncr_combine[['Division', 
                      'Enrollment_2005', 
                      'Enrollment_2006',
                      'Enrollment_2007', 
                     'Enrollment_2008', 
                     'Enrollment_2009',
                     'Enrollment_2010',
                     'Enrollment_2011',
                     'Enrollment_2012']].groupby('Division').sum()

# %%
ncr_combine
# Out:
#                   Enrollment_2005  Enrollment_2006  Enrollment_2007  \
# Division
# Caloocan City            282684.0         293070.0         297470.0
# City of San Juan              0.0              0.0              0.0
# Las Pinas City           110626.0         114472.0         117854.0
# Makati City               97828.0          97238.0         101586.0
# Malabon City             155362.0         158106.0         159810.0
# Mandaluyong City          54438.0          55958.0          56816.0
# Manila                   360466.0         366916.0         367160.0
# Marikina City             87626.0          90000.0          91518.0
# Muntinlupa City           81450.0          83436.0          87542.0
# NCR                     2296646.0        2355330.0        2399120.0
# Navotas                       0.0              0.0              0.0
# Paranaque City           101926.0         105472.0         106388.0
# Pasay City                69520.0          70344.0          70648.0
# ...

# %%
ncr_combine = ncr_combine.drop(['NCR'])
